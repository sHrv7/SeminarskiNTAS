# %% [markdown]
# # PRVI SEMINARSKI RAD 2026
#
# #### KOLEGIJ: Napredna teorija algoritama i sustava
#
# #### Datum predaje rada:
#
# #### Ime i prezime članova tima
#
# 1. Ime1
# 2. Ime2
# 3. Ime3
# 4. Ime4

# %% [markdown]
# ## POSTUPAK

# %% [markdown]
#  1.	Preuzimanje zadataka (po timovima) iz LMS-a predmeta.
#  2.	Rješenja zadataka u Jupyter Notebook obliku (tekstualni opis, kod,  rezultati, diskusija i zaključak) ili DOCX obliku uz priloženu implementaciju prema danom predlošku predati kao datoteku pod nazivom SEM1_TIMxy (xy - broj tima) u LMS predmeta. Rješenje predaje samo jedan član tima.
#  3. Rješenja zadataka treba predati do 7. svibnja 2026. u 23:59 u LMS sustav.

# %% [markdown]
# # OPIS ZADATKA

# %% [markdown]
# Korištenjem AVL balansiranog stabla implementirati stablo za indeksiranje zapisa iz baze podataka. Baza podataka u obliku tekstualne datoteke sadrži zapise o osobama. Podatkovni skup je zadan u datoteci *data.csv* te se sastoji više stotina tisuća zapisa.
# Struktura zapisa u datoteci je:
# *ime, prezime, spol, datum_rođenja, mjesto_stanovanja*
#
#
# **Svaki tim će imati drugi skup zapisa za obradu.**

# %% [markdown]
# ## ZADACI KOJE TREBA IMPLEMENTIRATI
#
# a) Učitati podatke iz datoteke u odgovarajuću strukturu.
#
# b) Na temelju sadržaja tekstualne datoteke treba izgraditi najprije obično pa onda i AVL binarno stablo pretraživanja uporabom razreda *BinaryTree* temeljem prezimena osobe kao primarnog indeksnog ključa te imena kao sekundarnog ključa. Ispisati visine dobivenih stabala. Usporediti vremena izgradnje.
#
# c) Ispisati minimalnu i maksimalnu vrijednost indeksa i pripadnih podataka za te indekse.
#
# d) Implementirati metode za ispis broja lijevih rotacija i broja desnih rotacija kod umetanja čvora u AVL stablo. Ispisati broj rotacija pri izgradnji AVL stabla.
#
# e) Ispisati stabla po razinama gdje čvorove svake razine treba ispisati u zasebnom retku. S obzirom na veliku količinu podataka dovoljno je ispisati samo prvih 10 razina.
#
# f) Implementirati pretraživanje podataka o osobama uporabom implementiranog indeksa i to tako da se za pretraživanje može zadati prezime u obliku prefiksa korištenjem znaka '\*'. Primjerice, može se unijeti cjelovito prezime 'Horvat' ili samo dio odnosno prefiks naziva 'Horv*'. Nakon što je podatak pronađen treba ispisati cijeli zapis o osobi. Usporediti vremena pretrage za obično i balansirano stablo.
#
# g) Implementirati funkciju za traženje osoba u rangu prezimena, primjerice sve osobe od '*Horv*' do '*Ivo*', ili od '*D*' do '*I*'. Rangove treba moći zadati proizvoljno. Usporediti vremena pretrage za obično i balansirano stablo.
#
# h) Sortirati zapise različitim algoritmima sortiranja uzevši kao ključ sortiranja prezime osobe. Ako dvije osobe imaju isto prezime kao drugi ključ sortiranja uzeti ime osobe. Usporediti algoritme po vremenu izvršavanja. Usporedbu vremena sortiranja potrebno je napraviti postepenim povećanjem nasumično izabranog podskupa zapisa koji se sortiraju: veličine 1000, 2000, 5000, 10000, 20000, 50000, 100000. Potrebno je implementirati i usporediti vremena sortiranja za algoritme sortiranja umetanjem, sortiranja spajanjem, brzog sortiranja i sortiranja balansiranim stablom.
#
# i) Ponoviti postupke b)-h) primijenivši datum rođenja i mjesto stanovanja kao indeksne ključeve (zasebno za svaki indeksni ključ).
#
# Timovi od 3 člana će imati skup podataka za trećinu manji od timova s 4 člana. Timovi od 2 člana će imati skup podataka koji je duplo manji od timova s 3 člana.
# U zadatku i) timovi od 3 člana trebaju napraviti implementirati samo jedan dodatni indeksni ključ od navedena dva. Timovi od 2 člana ne trebaju raditi zadatak i).
#
# Timovi mogu predložiti vlastitu podatkovni skup koji treba biti istog reda veličine kao i prvotno dodijeljeni te u tom slučaju timovi mogu dobiti 3 dodatna boda.
# U slučaju da tim samostalno implementira navedene zadatke i za crveno-crno stablo to se može bodovati za još 3 dodatna boda.
# Ukupan broj bodova na kolegiju je u svakom slučaju ograničen na ukupno 100 bodova.

# %% [markdown]
# # SADRŽAJ RADA

# %% [markdown]
# ## Opis implementacije

# %% [markdown]
# Opis implementacije i analiza složenosti rješenja zadataka.
# Napomena: Dati opis samo onog koda koji je vlastiti timu.

# %% [markdown]
# ## Prikaz rezultata

# %% [markdown]
# Opisati primijenjene ispitne slučajeve i komentirati rezultate.

# %% [markdown]
# ## Zaključak

# %% [markdown]
# Kratki zaključak.

# %% [markdown]
# ## Literatura

# %% [markdown]
# Popis literature:
#
# [1] Lit1
#
# [2] Lit2

# %% [markdown]
# # POČETNI PROGRAMSKI KÔD
#
# #### Implementacija AVL stabla

# %%
class BinaryNode:

    def __init__ (self, value = None):
        """Create binary node."""
        self.value  = value
        self.left   = None
        self.right  = None
        self.height = 0
        
        
    def computeHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.height)
        if self.right:
            height = max(height, self.right.height)
            
        self.height = height + 1

    def dynamicHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.dynamicHeight())
        if self.right:
            height = max(height, self.right.dynamicHeight())
            
        return height + 1

    def dynamicHeightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.dynamicHeight()
        if self.right:
            rightTarget = 1 + self.right.dynamicHeight()
            
        return leftTarget - rightTarget

    def heightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.height
        if self.right:
             rightTarget = 1 + self.right.height
                   
        return leftTarget - rightTarget

    def assertAVLProperty (self):
        """Validate AVL property for BST node."""
        if abs(self.dynamicHeightDifference()) > 1:
            return False
        if self.left:
            if not self.left.assertAVLProperty():
                return False
        if self.right:
            if not self.right.assertAVLProperty():
                return False

        return True

    def rotateRight (self):
        """Perform right rotation around given node."""
        newRoot = self.left
        grandson = newRoot.right
        self.left = grandson
        newRoot.right = self

        self.computeHeight()
        
        return newRoot

    def rotateLeft (self):
        """Perform left rotation around given node."""
        newRoot = self.right
        grandson = newRoot.left
        self.right = grandson
        newRoot.left = self
    
        self.computeHeight()
        return newRoot

    def rotateLeftRight (self):
        """Perform left, then right rotation around given node."""
        child = self.left
        newRoot = child.right
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.right = grand1
        self.left = grand2
    
        newRoot.left = child
        newRoot.right = self
    
        child.computeHeight()
        self.computeHeight()
        
        return newRoot

    def rotateRightLeft (self):
        """Perform right, then left rotation around given node."""
        child = self.right
        newRoot = child.left
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.left = grand2
        self.right = grand1
    
        newRoot.left = self
        newRoot.right = child
    
        child.computeHeight()
        self.computeHeight()
      
        return newRoot
    
    def compareTo (self, value):
        """
        Returns 0 if equal, negative if smaller and positive if greater.
        Suitable for overriding.
        """
        if self.value == value:
            return 0
        if self.value < value:
            return -1
        return +1
        
    def add (self, val):
        """Adds a new node to BST with value and rebalance as needed."""
        newRoot = self

        # if val <= self.value        
        if self.compareTo(val) >= 0:
            self.left = self.addToSubTree (self.left, val)
            if self.heightDifference() == 2:
                #if val <= self.left.value:
                
                if self.left.compareTo(val) >= 0:
                    newRoot = self.rotateRight()
                else:
                    newRoot = self.rotateLeftRight()
        else:
            self.right = self.addToSubTree (self.right, val)
            if self.heightDifference() == -2:
                #if val > self.right.value:
                if self.right.compareTo(val) < 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()

        newRoot.computeHeight()
        return newRoot

    def newNode (self, val):
        """Return new Binary Node, amenable to subclassing."""
        return BinaryNode(val)

    def addToSubTree (self, parent, val):
        """Add val to parent subtree (if exists) and return root in case it has changed because of rotation."""
        if parent is None:
            return self.newNode(val)

        parent = parent.add(val)
        return parent
           
    def removeFromParent (self, parent, val):
        """Helper method for remove. Ensures proper behavior when removing node that 
        has children."""
        if parent:
            return parent.remove(val)
        return None

    def remove (self, val):
        """
         Remove val from BinaryTree. Works in conjunction with remove
         method in BinaryTree.
        """
        newRoot = self
        rc = self.compareTo(val)
        if rc == 0:
            if self.left is None:
                return self.right

            child = self.left
            while child.right:
                child = child.right
            
            childKey = child.value;
            self.left = self.removeFromParent(self.left, childKey)
            self.value = childKey;

            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        elif rc > 0:
            self.left = self.removeFromParent(self.left, val)
            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        else:
            self.right = self.removeFromParent(self.right, val)
            if self.heightDifference() == 2:
                if self.left.heightDifference() >= 0:
                    newRoot = self.rotateRight()
                else:
                    newRoot = self.rotateLeftRight()

        newRoot.computeHeight()
        return newRoot

    def __repr__ (self):
        """Useful debugging function to produce linear tree representation."""
        leftS = ''
        rightS = ''
        if self.left:
            leftS = str(self.left)
        if self.right:
            rightS = str(self.right)
        return "(L:" + leftS + " " + str(self.value) + " R:" + rightS + ")"

    def inorder (self):
        """In order traversal generator of tree rooted at given node."""
        if self.left:
            for n in self.left.inorder():
                yield n

        yield self.value

        if self.right:
            for n in self.right.inorder():
                yield n

class BinaryTree:

    def __init__ (self):
        """Create empty binary tree."""
        self.root = None

    def __repr__ (self):
        if self.root is None:
            return "avl:()"
        return "avl:" + str(self.root)
                
    def newNode (self, value):
        """Return new BinaryNode object. Suitable for overriding."""
        return BinaryNode(value)
    
    def add (self, value):
        """Insert value into proper location in Binary Tree."""
        if self.root is None:
            self.root = self.newNode(value)
        else:
            self.root = self.root.add(value)

    def __contains__ (self, target):
        """Check whether BST contains target value."""
        node = self.root
        while node:
            rc = node.compareTo(target)
            if rc > 0:
                node = node.left
            elif rc < 0:
                node = node.right
            else:
                return True
        return False

           
    def remove (self, val):
        """Remove value from tree."""
        if self.root:
            self.root = self.root.remove(val)

    def __iter__ (self):          # definira iteriranje kroz inorder ispis
        """In order traversal of elements in the tree."""
        if self.root:
            return self.root.inorder()
                        
    def assertAVLProperty (self):
        """Validate AVL property for BST Tree."""
        if self.root:
            return self.root.assertAVLProperty()
        else:
            return True
        
    
    def _compare_keys(self, person, key):
        """Uspoređuje osobu s ključem (prezime, ime)."""
        if isinstance(key, str):
            return (person.prezime > key) - (person.prezime < key)
        elif isinstance(key, tuple) and len(key) == 2:
            prezime_cmp = (person.prezime > key[0]) - (person.prezime < key[0])
            if prezime_cmp != 0:
                return prezime_cmp
            return (person.ime > key[1]) - (person.ime < key[1])
        else:
            raise ValueError("Invalid key format")

# %%
class PersonAVLNode(BinaryNode):
    def compareTo(self, other):
        """
        Uspoređuje osobe po prezimenu, pa po imenu.
        """
        if not isinstance(other, Osoba):
            return super().compareTo(other)
        
        # Usporedba po prezimenu
        prezime_cmp = (self.value.prezime > other.prezime) - (self.value.prezime < other.prezime)
        if prezime_cmp != 0:
            return prezime_cmp
        
        # Ako prezimena jednaka, usporedba po imenu
        ime_cmp = (self.value.ime > other.ime) - (self.value.ime < other.ime)
        return ime_cmp

class PersonBinaryNode(BinaryNode):
    """Obični BST čvor bez rotacija za osobe."""
    
    def add(self, val):
        """Dodaje čvor bez balansiranja."""
        if self.compareTo(val) >= 0:
            if self.left is None:
                self.left = self.newNode(val)
            else:
                self.left = self.left.add(val)
        else:
            if self.right is None:
                self.right = self.newNode(val)
            else:
                self.right = self.right.add(val)
        
        self.computeHeight()
        return self
    
    def compareTo(self, other):
        """
        Uspoređuje osobe po prezimenu, pa po imenu.
        """
        if not isinstance(other, Osoba):
            return super().compareTo(other)
        
        # Usporedba po prezimenu
        prezime_cmp = (self.value.prezime > other.prezime) - (self.value.prezime < other.prezime)
        if prezime_cmp != 0:
            return prezime_cmp
        
        # Ako prezimena jednaka, usporedba po imenu
        ime_cmp = (self.value.ime > other.ime) - (self.value.ime < other.ime)
        return ime_cmp
    
    def newNode(self, val):
        """Vraća novi PersonBinaryNode."""
        return PersonBinaryNode(val)

class BinarySearchTree(BinaryTree):
    """Obično binarno stablo pretraživanja bez balansiranja za osobe."""
    
    def newNode(self, value):
        return PersonBinaryNode(value)

# %%
class PersonAVLNode(BinaryNode):
    # Globalni brojač rotacija
    rotation_count = 0
    left_rotation_count = 0
    right_rotation_count = 0
        
    def rotateRight(self):
        """Perform right rotation around given node."""
        PersonAVLNode.rotation_count += 1
        PersonAVLNode.right_rotation_count += 1
        return super().rotateRight()

    def rotateLeft(self):
        """Perform left rotation around given node."""
        PersonAVLNode.rotation_count += 1
        PersonAVLNode.left_rotation_count += 1
        return super().rotateLeft()

    def rotateLeftRight(self):
        """Perform left, then right rotation around given node."""
        PersonAVLNode.rotation_count += 2
        PersonAVLNode.left_rotation_count += 1
        PersonAVLNode.right_rotation_count += 1
        return super().rotateLeftRight()

    def rotateRightLeft(self):
        """Perform right, then left rotation around given node."""
        PersonAVLNode.rotation_count += 2
        PersonAVLNode.right_rotation_count += 1
        PersonAVLNode.left_rotation_count += 1
        return super().rotateRightLeft()

class PersonBinaryNode(BinaryNode):
    """Obični BST čvor bez rotacija za osobe."""
    
    def add(self, val):
        """Dodaje čvor bez balansiranja."""
        if self.compareTo(val) >= 0:
            if self.left is None:
                self.left = self.newNode(val)
            else:
                self.left = self.left.add(val)
        else:
            if self.right is None:
                self.right = self.newNode(val)
            else:
                self.right = self.right.add(val)
        
        self.computeHeight()
        return self
    
    def newNode(self, val):
        """Vraća novi PersonBinaryNode."""
        return PersonBinaryNode(val)

class BinarySearchTree(BinaryTree):
    """Obično binarno stablo pretraživanja bez balansiranja za osobe."""
    
    def newNode(self, value):
        return PersonBinaryNode(value)
    
class AVLSearchTree(BinaryTree):
    """AVL balansirano stablo pretraživanja za osobe."""
    
    def newNode(self, value):
        return PersonAVLNode(value)
    
    def get_rotation_stats(self):
        """Vraća statistiku rotacija."""
        return {
            'total': PersonAVLNode.rotation_count,
            'left': PersonAVLNode.left_rotation_count,
            'right': PersonAVLNode.right_rotation_count
        }
    
    def reset_rotation_stats(self):
        """Resetira brojače rotacija."""
        PersonAVLNode.rotation_count = 0
        PersonAVLNode.left_rotation_count = 0
        PersonAVLNode.right_rotation_count = 0

# %% [markdown]
# #### Primjer koda (s cjelobrojnim ključevima) za rukovanje AVL stablom.

# %%
if __name__ == '__main__':
    import random
    myTree = BinaryTree() 
    
    # umetanje nasumične vrijednosti u stablo
    vals = []
    for _ in range(8000):
        n = random.randint(1,10000)
        vals.append(n)
        if not n in myTree:
            myTree.add(n)
      

    #  iteriranje kroz stablo - inorder() - samo ispis vrijednosti između 100 i 200
    #  koristi se metoda __iter__()
    for x in myTree:   
        if x > 100 and x < 200:
            print(x)

    # remove all
    for r in vals:
        myTree.remove(r)
# Out:
# 101
# 104
# 109
# 111
# 112
# 114
# 115
# 116
# 119
# 122
# 123
# 125
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 142
# 143
# 144
# 148
# 150
# 152
# 154
# 155
# 157
# 158
# 161
# 162
# 165
# 168
# 169
# 170
# 172
# 173
# 174
# 175
# 176
# 178
# 180
# 182
# 183
# 187
# 188
# 189
# 190
# 192
# 195
# 196
# 198

# %% [markdown]
# # IMPLEMENTACIJA ISPITNOG KODA SUKLADNO ZADACIMA
#
# Za svaki ispitni kôd formirati posebni pokretač:

# %%
if __name__ == '__main__':
    pass

# %% [markdown]
# ### a) Učitavanje podataka

# %%
import csv
from collections import namedtuple

# Definiramo strukturu za osobu
Osoba = namedtuple('Osoba', ['ime', 'prezime', 'spol', 'datum_rodenja', 'mjesto_stanovanja'])

def ucitaj_podatke(datoteka):
    """Učitava podatke iz CSV datoteke i vraća listu objekata Osoba."""
    osobe = []
    with open(datoteka, 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) == 5:
                osoba = Osoba(*(value.strip() for value in row))
                osobe.append(osoba)
    return osobe


def format_person_name(person):
    """Vraća prikaz prezimena i imena s oznakom za prazno ime."""
    ime = person.ime.strip()
    if ime == "":
        ime = "<prazno>"
    return f"{person.prezime}, {ime}"

# Učitavanje podataka

datoteka = 'podatkovni_skup_Zirdum.csv'
osobe = ucitaj_podatke(datoteka)
print(f"Učitano {len(osobe)} osoba.")

for osoba in osobe[:5]:  # Prikaz prvih 5 osoba
    print(osoba)
# Out:
# Učitano 1000000 osoba.
# Osoba(ime='Frana', prezime='Radoš', spol='Ž', datum_rodenja='09.08.1994', mjesto_stanovanja='Budinščina')
# Osoba(ime='Zorko', prezime='Križanec', spol='M', datum_rodenja='30.03.1964', mjesto_stanovanja='Donji Miholjac')
# Osoba(ime='Biljana', prezime='Kardum', spol='Ž', datum_rodenja='19.10.1991', mjesto_stanovanja='Zagvozd')
# Osoba(ime='Jan', prezime='Krajinović', spol='M', datum_rodenja='17.10.1995', mjesto_stanovanja='Petrijanec')
# Osoba(ime='Dean', prezime='Mihalić', spol='M', datum_rodenja='04.07.1967', mjesto_stanovanja='Sveti Petar u Šumi')

# %% [markdown]
# ### b) Izgradnja indeksa

# %%
import time

# Izgradnja običnog BST
print("Izgradnja običnog BST stabla...")
start_time = time.time()
bst_tree = BinarySearchTree()
test_osobe = osobe  # Koristimo sve podatke
for osoba in test_osobe:
    bst_tree.add(osoba)
bst_time = time.time() - start_time
bst_height = bst_tree.root.height if bst_tree.root else 0
print(f"Obično BST stablo izgrađeno u {bst_time:.4f} sekundi. Visina: {bst_height}")

# Izgradnja AVL stabla
print("Izgradnja AVL stabla...")
start_time = time.time()
avl_tree = AVLSearchTree()
for osoba in test_osobe:
    avl_tree.add(osoba)
avl_time = time.time() - start_time
avl_height = avl_tree.root.height if avl_tree.root else 0
print(f"AVL stablo izgrađeno u {avl_time:.4f} sekundi. Visina: {avl_height}")

print(f"\nUsporedba vremena izgradnje:")
print(f"Obično BST: {bst_time:.4f} s")
print(f"AVL: {avl_time:.4f} s")
print(f"AVL je {bst_time/avl_time:.2f}x brže od običnog BST" if bst_time > avl_time else f"Obično BST je {avl_time/bst_time:.2f}x brže od AVL")
# Out:
# Izgradnja običnog BST stabla...
# Obično BST stablo izgrađeno u 15.8171 sekundi. Visina: 51
# Izgradnja AVL stabla...
# AVL stablo izgrađeno u 16.9439 sekundi. Visina: 23
#
# Usporedba vremena izgradnje:
# Obično BST: 15.8171 s
# AVL: 16.9439 s
# Obično BST je 1.07x brže od AVL

# %% [markdown]
# ### c) Minimalna i maksimalna vrijednost indeksa

# %%
def get_min_max_from_tree(tree):
    """Pronalazi minimalnu i maksimalnu vrijednost u stablu (inorder traversal)."""
    if not tree.root:
        return None, None
    
    values = list(tree)
    return values[0], values[-1]

# Pronalaženje min/max za BST
bst_min, bst_max = get_min_max_from_tree(bst_tree)
print("=" * 60)
print("MINIMALNA I MAKSIMALNA VRIJEDNOST INDEKSA")
print("=" * 60)
print("\nObično BST:")
if bst_min:
    print(f"Minimalna vrijednost (prezime): {format_person_name(bst_min)}")
    print(f"  Podaci: Ime={bst_min.ime or '<prazno>'}, Prezime={bst_min.prezime}, Spol={bst_min.spol}, Datum={bst_min.datum_rodenja}, Mjesto={bst_min.mjesto_stanovanja}")
if bst_max:
    print(f"Maksimalna vrijednost (prezime): {format_person_name(bst_max)}")
    print(f"  Podaci: Ime={bst_max.ime or '<prazno>'}, Prezime={bst_max.prezime}, Spol={bst_max.spol}, Datum={bst_max.datum_rodenja}, Mjesto={bst_max.mjesto_stanovanja}")

# Pronalaženje min/max za AVL
avl_min, avl_max = get_min_max_from_tree(avl_tree)
print("\nAVL stablo:")
if avl_min:
    print(f"Minimalna vrijednost (prezime): {format_person_name(avl_min)}")
    print(f"  Podaci: Ime={avl_min.ime or '<prazno>'}, Prezime={avl_min.prezime}, Spol={avl_min.spol}, Datum={avl_min.datum_rodenja}, Mjesto={avl_min.mjesto_stanovanja}")
if avl_max:
    print(f"Maksimalna vrijednost (prezime): {format_person_name(avl_max)}")
    print(f"  Podaci: Ime={avl_max.ime or '<prazno>'}, Prezime={avl_max.prezime}, Spol={avl_max.spol}, Datum={avl_max.datum_rodenja}, Mjesto={avl_max.mjesto_stanovanja}")
# Out:
# ============================================================
# MINIMALNA I MAKSIMALNA VRIJEDNOST INDEKSA
# ============================================================
#
# Obično BST:
# Minimalna vrijednost (prezime): Abramović, <prazno>
#   Podaci: Ime=<prazno>, Prezime=Abramović, Spol=Ž, Datum=18.01.1989, Mjesto=Velika Ludina
# Maksimalna vrijednost (prezime): Žuvela, Živko
#   Podaci: Ime=Živko, Prezime=Žuvela, Spol=M, Datum=22.01.1972, Mjesto=Viškovo
#
# AVL stablo:
# Minimalna vrijednost (prezime): Abramović, <prazno>
#   Podaci: Ime=<prazno>, Prezime=Abramović, Spol=Ž, Datum=18.01.1989, Mjesto=Velika Ludina
# Maksimalna vrijednost (prezime): Žuvela, Živko
#   Podaci: Ime=Živko, Prezime=Žuvela, Spol=M, Datum=22.01.1972, Mjesto=Viškovo

# %% [markdown]
# ### d) Broj rotacija pri izgradnji AVL stabla

# %%
print("\n" + "=" * 60)
print("BROJ ROTACIJA PRI IZGRADNJI AVL STABLA")
print("=" * 60)

# Resetiraj brojače i ponovno izgradi AVL stablo
PersonAVLNode.rotation_count = 0
PersonAVLNode.left_rotation_count = 0
PersonAVLNode.right_rotation_count = 0

avl_tree_counted = AVLSearchTree()
for osoba in test_osobe:
    avl_tree_counted.add(osoba)

stats = avl_tree_counted.get_rotation_stats()
print(f"\nRotacije pri izgradnji AVL stabla:")
print(f"  Ukupno rotacija: {stats['total']}")
print(f"  Lijeve rotacije: {stats['left']}")
print(f"  Desne rotacije: {stats['right']}")
# Out:
# ============================================================
# BROJ ROTACIJA PRI IZGRADNJI AVL STABLA
# ============================================================
#
# Rotacije pri izgradnji AVL stabla:
#   Ukupno rotacija: 15
#   Lijeve rotacije: 9
#   Desne rotacije: 6

# %% [markdown]
# ### e) Ispis stabla po razinama (prvih 10 razina)

# %%
from collections import deque

def print_tree_by_levels(tree, max_levels=10):
    """Ispisuje stablo po razinama (level-order traversal) do max_levels razina."""
    if not tree.root:
        print("Stablo je prazno.")
        return
    
    queue = deque([(tree.root, 0)])  # (čvor, razina)
    current_level = 0
    level_nodes = []
                                                                                                                                                                                                                                                                                                                                                                                                                                                    
    while queue and current_level < max_levels:
        node, level = queue.popleft()
        
        if level > current_level:
            # Ispisuj prethodnu razinu
            print(f"Razina {current_level}: {level_nodes}")
            level_nodes = []
            current_level = level
        
        if current_level < max_levels:
            # Dodaj prezime i ime čvora
            level_nodes.append(f"{node.value.prezime},{node.value.ime}")
            
            if node.left:
                queue.append((node.left, level + 1))
            if node.right:
                queue.append((node.right, level + 1))
    
    if level_nodes:
        print(f"Razina {current_level}: {level_nodes}")

print("\n" + "=" * 60)
print("ISPIS STABLA PO RAZINAMA (PRVIH 10 RAZINA)")
print("=" * 60)

print("\nObično BST:")
print_tree_by_levels(bst_tree, max_levels=10)

print("\nAVL stablo:")
print_tree_by_levels(avl_tree_counted, max_levels=10)
# Out:
# ============================================================
# ISPIS STABLA PO RAZINAMA (PRVIH 10 RAZINA)
# ============================================================
#
# Obično BST:
# Razina 0: ['Radoš,Frana']
# Razina 1: ['Kardum,Biljana', 'Križanec,Zorko']
# Razina 2: ['Padovan,Anela', 'Mihalić,Dean', 'Krajinović,Jan', 'Žeželj,Zvonko']
# Razina 3: ['Vujnović,Alma', 'Frančić,Antun', 'Jerković,Branimir', 'Vukelić,Doris', 'Kranjec,Indira', 'Bertić,Jure', 'Panić,Zorko', 'Maršić,Đorđe']
# Razina 4: ['Matković,Albert', 'Galić,Anastazija', 'Crnić,Antonela', 'Lovrenčić,Anđelo', 'Pleša,Bogdan', 'Antolović,Darija', 'Radojčić,Deana', 'Perak,Edita', 'Franić,Helena', 'Andrijanić,Ivana', 'Janeš,Jerolim', 'Špiranec,Neven', 'Novaković,Zorko', 'Petek,Zrinka', 'Pavić,Čedo', 'Zubčić,Živko']
'Bilandžić,Antica', 'Gorički,Anton', 'Škreblin,Anton', 'Majdandžić,Antonela', 'Mirić,Antonia', 'Dizdarević,Antonija', 'Jakus,Antonija', 'Skender,Antonija', 'Pešut,Antonijo', 'Ranogajec,Antonio', 'Bugarin,Antun', 'Hodak,Antun', 'Knez,Antun', 'Nakić,Antun', 'Rešetar,Antun', 'Jagnjić,Ančica', 'Jozić,Anđela', 'Goreta,Anđelka', 'Prpić,Anđelko', 'Augustinović,Arsen', 'Lozančić,August', 'Đurašin,August', 'Golub,Bara', 'Šantek,Bartol', 'Andrijanić,Bartul', 'Pejković,Benjamin', 'Čuljak,Bernardica', 'Kukić,Biljana', 'Tomas,Biljana', 'Antunović,Biserka', 'Vulić,Biserka', 'Perica,Blago', 'Božić,Blaženko', 'Matijašić,Bogdan', 'Plazibat,Bogdan', 'Glavan,Boris', 'Radić,Boško', 'Dizdarević,Božena', 'Bartolović,Božidar', 'Lukač,Božidar', 'Čulić,Božidar', 'Hodžić,Branimir', 'Jergović,Branimir', 'Magdić,Branimir', 'Kapetanović,Branislav', 'Matulić,Branislava', 'Dujić,Brankica', 'Morić,Branko', 'Ivošević,Danijela', 'Lulić,Dara', 'Kožul,Daria', 'Barać,Darija', 'Komar,Darinko', 'Plazibat,Dario', 'Kranjec,Darko', 'Zadravec,Davorin', 'Batinić,Dean', 'Ivančan,Dean', 'Martinjak,Dean', 'Nikšić,Dean', 'Zec,Dean', 'Bušljeta,Deana', 'Gudelj,Deana', 'Ivandić,Deana', 'Ivković,Deana', 'Mustač,Deana', 'Radman,Deana', 'Vidović,Deana', 'Bukovac,Dejan', 'Cvitković,Dejan', 'Dedić,Dejan', 'Bašić,Dejana', 'Štajduhar,Deni', 'Posavac,Desanka', 'Brlić,Domagoj', 'Đaković,Doris', 'Brkić,Dorotea', 'Grbeša,Dorotea', 'Jakić,Dorotea', 'Parlov,Dubravka', 'Sedlar,Dušanka', 'Nenadić,Eda', 'Grbeša,Edita', 'Puljiz,Edita', 'Grdić,Elda', 'Gorički,Eleonora', 'Anić,Ema', 'Bogdanić,Emilija', 'Zelić,Estera', 'Sakač,Ferdinand', 'Krpan,Frana', 'Samardžić,Franc', 'Bobinac,Franciska', 'Jozić,Franciska', 'Tomljenović,Frane', 'Žuvela,Franica', 'Maleš,Goran', 'Lukačević,Grga', 'Molnar,Hedviga', 'Bogdanović,Helga', 'Pernar,Hermina', 'Hršak,Igor', 'Dumenčić,Ilona', 'Lončarević,Ilona', 'Kožić,Ilonka', 'Carević,Ina', 'Balog,Ines', 'Benković,Irena', 'Brezak,Irma', 'Trogrlić,Iskra', 'Banović,Ivan', 'Ivanković,Ivan', 'Knežić,Ivan', 'Vidas,Ivan', 'Klasić,Ivana', 'Kurtović,Ivanka', 'Benčić,Ive', 'Sekulić,Ivona', 'Begović,Izidor', 'Đurin,Jagica', 'Marević,Jaka', 'Marić,Jakov', 'Kraljević,Jan', 'Ružić,Jan', 'Uzelac,Jan', 'Zečević,Jan', 'Marušić
enčić,Andrija', 'Jakus,Andrija', 'Rebić,Ane', 'Avdić,Anela', 'Nikić,Anela', 'Stipetić,Anela', 'Bukovac,Angela', 'Župan,Anica', 'Paradžik,Anja', 'Rončević,Ankica', 'Stipanović,Ankica', 'Subotić,Ankica', 'Sušanj,Ankica', 'Tomić,Ankica', 'Višić,Ankica', 'Sedlar,Ante', 'Vojković,Antica', 'Martić,Anto', 'Jurčević,Anton', 'Pintar,Anton', 'Arbanas,Antonela', 'Damjanović,Antonela', 'Čolak,Antonela', 'Lukšić,Antonia', 'Radanović,Antonia', 'Debeljak,Antonija', 'Drašković,Antonija', 'Gašparić,Antonija', 'Klobučar,Antonija', 'Rašić,Antonija', 'Duspara,Antonijo', 'Obradović,Antonijo', 'Đurđević,Antonijo', 'Dolić,Antonio', 'Težak,Antonio', 'Budić,Antun', 'Dolić,Antun', 'Golub,Antun', 'Hršak,Antun', 'Jakopec,Antun', 'Kutnjak,Antun', 'Matijaš,Antun', 'Pehar,Antun', 'Petric,Antun', 'Crljen,Ančica', 'Gvozdanović,Ančica', 'Knežević,Ančica', 'Bunjevac,Anđa', 'Čaušević,Anđelija', 'Andrijević,Anđelina', 'Ravlić,Anđelka', 'Bošković,Anđelko', 'Benić,Anđelo', 'Radaković,Ariana', 'Kolak,Arsen', 'Ljubičić,August', 'Lozić,August', 'Markotić,August', 'Kanižaj,Azra', 'Bezjak,Bara', 'Vukas,Bara', 'Sabo,Bartol', 'Šestan,Bartol', 'Alfirević,Bartul', 'Kiš,Bartul', 'Pavleković,Bartul', 'Bunić,Berislav', 'Trstenjak,Bernardica', 'Gregurić,Biljana', 'Kolarić,Biljana', 'Matić,Biljana', 'Rebić,Biljana', 'Zajec,Biljana', 'Šarić,Biljana', 'Cvrtila,Biserka', 'Jurčević,Biserka', 'Begić,Blago', 'Crljen,Blago', 'Peršić,Blago', 'Grgurević,Blanka', 'Jakopec,Blaženko', 'Martić,Bogdan', 'Milković,Bogdan', 'Pavković,Bogdan', 'Plazonić,Bogdan', 'Gašpar,Bojana', 'Jerković,Borislav', 'Turčić,Borivoj', 'Gržinić,Božana', 'Bišćan,Božena', 'Jurić,Božena', 'Zagorec,Božena', 'Grbić,Božidar', 'Lacković,Božidar', 'Lukačić,Božidar', 'Čulić,Božidar', 'Hrvatin,Božo', 'Jakopović,Branimir', 'Jerković,Branimir', 'Klasić,Branimir', 'Posavac,Branimir', 'Gabrić,Branislav', 'Nemet,Branislav', 'Peša,Branislav', 'Šimunec,Branislava', 'Domić,Brankica', 'Furjan,Brankica', 'Hercigonja,Brankica', 'Bikić,Cvijeta', 'Dujić,Damjan', 'Juretić,Danijela', 'Komar,Dara', 'Čačić,Dara', 'Dujmović,Daria', 'Lalić,Daria', 'Banović,Darija', 'Pavlek,Darija', 'Dumenčić,Darinka', 'Sokač,Darinko', 'Marjanović,Dario', 'Škorić,Dario', 'Mrkonjić,Darka', 'Šebalj,Davor', 'Vrdoljak,Davorin', 'Drmić,Davorka', 'Vuksanović,Davorka', 'Bekavac,Dean', 'Hercigonja,Dean', 'Knežević,Dean', 'Matas,Dean', 'Mišić,Dean', 'Spajić,Dean', 'Vulić,Dean', 'Štefančić,Dean', 'Bušić,Deana', 'Dujmić,Deana', 'Grujić,Deana', 'Hadžić,Deana', 'Ivandić,Deana', 'Ivančić,Deana', 'Lozić,Deana', 'Modrušan,Deana', 'Opačak,Deana', 'Popović,Deana', 'Radman,Deana', 'Tomašković,Deana', 'Vrban,Deana', 'Batinić,Dejan', 'Crnić,Dejan', 'Cvitković,Dejan', 'Debeljak,Dejan', 'Delić,Dejan', 'Katalenić,Dejan', 'Radelić,Dejana', 'Stojčević,Deni', 'Bušić,Desanka', 'Jović,Desanka', 'Barbarić,Dolores', 'Soldo,Dolores', 'Đurašin,Domagoj', 'Vukoja,Doris', 'Štefanec,Doris', 'Boršić,Dorotea', 'Dugandžić,Dorotea', 'Golubić,Dorotea', 'Halužan,Dorotea', 'Jagnjić,Dorotea', 'Jakić,Dorotea', 'Sever,Drag ...
#
# AVL stablo:
# Razina 0: ['Bertić,Jure']
# Razina 1: ['Mihalić,Dean', 'Špiranec,Neven']
# Razina 2: ['Lovrenčić,Anđelo', 'Grubić,Franica', 'Balić,Marijana', 'Borovec,Tihana']
# Razina 3: ['Galić,Anastazija', 'Prskalo,Bože', 'Botić,Duška', 'Benčić,Ive', 'Sinković,Livija', 'Vojković,Mile', 'Lozančić,Sanjin', 'Hodak,Vlatka']
# Razina 4: ['Volarić,Albina', 'Tolić,Ankica', 'Radovanović,Blago', 'Drakulić,Daniel', 'Vukelić,Doris', 'Morić,Erika', 'Franić,Helena', 'Kuzmić,Jelica', 'Crnić,Krešo', 'Dropulić,Lučano', 'Grozdanić,Matej', 'Vuk,Momčilo', 'Žuvela,Radojka', 'Domitrović,Sofija', 'Levak,Vesela', 'Križanec,Zorko']
# Razina 5: ['Dumenčić,Adrijana', 'Vujnović,Alma', 'Padovan,Anela', 'Frančić,Antun', 'Kuzmanović,Bartul', 'Janjić,Boris', 'Dražić,Cvijeta', 'Drašković,Dara', 'Kukec,Dinka', 'Banić,Dragutin', 'Hodak,Elio', 'Vlahović,Fabijan', 'Kukić,Gordan', 'Kranjec,Indira', 'Šarčević,Jan', 'Ribić,Josipa', 'Roso,Katija', 'Žaja,Lazo', 'Glavaš,Ljudevit', 'Antolović,Manuela', 'Anđelić,Mario', 'Živković,Meri', 'Vukšić,Milovan', 'Luketić,Nedo', 'Hršak,Patricija', 'Ercegović,Romina', 'Radošević,Slavko', 'Peršić,Sunčica', 'Stojković,Uroš', 'Kos,Višnja', 'Majić,Zdravka', 'Škreblin,Đurđica']
# Razina 6: ['Zečević,Adam', 'Tolić,Alan', 'Kušić,Alen', 'Matanović,Amalija', 'Jakus,Andrija', 'Ramljak,Anica', 'Crnić,Antonela', 'Šestan,Anđelija', 'Đurašin,August', 'Peršić,Bernarda', 'Pleša,Bogdan', 'Lasić,Borna', 'Dadić,Brankica', 'Sokač,Damir', 'Došen,Danira', 'Krajnović,Darka', 'Štajduhar,Deni', 'Barbarić,Dolores', 'Blažeković,Dragica', 'Parlov,Dubravka', 'Rajković,Edvard', 'Butorac,Emilija', 'Zekić,Estera', 'Šimunović,Florijan', 'Banović,Gabrijel', 'Lukačević,Grga', 'Hršak,Igor', 'Boban,Iris', 'Bičanić,Jadranko', 'Križan,Jasmina', 'Bilandžić,Jolanda', 'Kožić,Jožef', 'Došen,Karmela', 'Radošević,Klaudio', 'Buneta,Ksenija', 'Ćorluka,Leona', 'Simić,Ljuban', 'Borković,Luca', 'Barešić,Manda', 'Žganec,Mare', 'Gavran,Marin', 'Dražić,Maro', 'Novoselac,Mato', 'Adamović,Mijat', 'Kiš,Miljenko', 'Puškarić,Mirko', 'Todorović,Nađa', 'Dadić,Nensi', 'Šipek,Nikša', 'Bićanić,Pejo', 'Franjković,Rikard', 'Budić,Sabina', 'Molnar,Silvije', 'Vučić,Slobodanka', 'Bilić,Stevo', 'Mikulec,Tajana', 'Petrić,Toma', 'Domitrović,Vanja', 'Radić,Vida', 'Borčić,Vladimir', 'Rimac,Vojko', 'Čović,Zlatka', 'Žeželj,Zvonko', 'Petranović,Žarko']
# Razina 7: ['Varga,', 'Stanić,Adolf', 'Marković,Agneza', 'Cvitanović,Albin', 'Brajdić,Aleksandra', 'Lukačević,Alfred', 'Vincetić,Alojzija', 'Vukasović,Ana-Marija', 'Grdić,Andrej', 'Belošević,Andro', 'Zubčić,Angela', 'Borović,Anka', 'Plazibat,Antica', 'Kovačević,Antonija', 'Bunjevac,Anđa', 'Arbanas,Anđelko', 'Augustinović,Arsen', 'Vukas,Bara', 'Bunić,Berislav', 'Rebić,Biljana', 'Pejković,Blaženka', 'Kokić,Bojan', 'Maretić,Borka', 'Antolić,Boško', 'Jerković,Branimir', 'Stančić,Bruno', 'Rožić,Dajana', 'Rosandić,Damjan', 'Ivošević,Danijela', 'Blažeković,Danko', 'Dumenčić,Darinka', 'Ljubas,Davor', 'Bašić,Dejana', 'Grujić,Dijana', 'Krstulović,Divna', 'Puškarić,Dominik', 'Sever,Draga', 'Perković,Drago', 'Kosanović,Dražena', 'Vorkapić,Dunja', 'Pezelj,Edi', 'Hršak,Elena', 'Dolenec,Ema', 'Begić,Ena', 'Borović,Ervin', 'Novaković,Eva', 'Sakač,Ferdinand', 'Jozić,Franciska', 'Pavić,Franjo', 'Maleš,Goran', 'Ćurković,Gordana', 'Petrović,Grozdana', 'Rogić,Hermina', 'Jozić,Ilinka', 'Abramović,Ingrid', 'Trogrlić,Iskra', 'Gavran,Ivo', 'Manojlović,Jaka', 'Marušić,Janja', 'Pešut,Jasna', 'Bobanović,Jerka', 'Vasilj,Jordan', 'Husnjak,Jovo', 'Bunjevac,Julijana', 'Jozić,Kaja', 'Borić,Kata', 'Rogić,Kažimir', 'Mitrović,Koraljka', 'Davidović,Krsto', 'Cvetko,Larisa', 'Kardum,Leo', 'Čolić,Lidija', 'Matijaš,Ljilja', 'Vukas,Ljubiša', 'Pleše,Loreta', 'Jakovljević,Lucijan', 'Štrbac,Magda', 'Prgomet,Mandica', 'Čagalj,Marcel', 'Bugarin,Marica', 'Paulić,Marijanka', 'Baljak,Marinka', 'Dokić,Marjana', 'Kramar,Martin', 'Jerbić,Matija', 'Troskot,Melanija', 'Živko,Mihaela', 'Dukarić,Milan', 'Skupnjak,Milenko', 'Husnjak,Milko', 'Brkljačić,Miran', 'Grbavac,Miško', 'Požgaj,Nadežda', 'Kolar,Nediljko', 'Opačak,Nena', 'Brković,Nermin', 'Kraljić,Nikica', 'Zubčić,Oliver', 'Burić,Pavao', 'Borojević,Rada', 'Čačić,Ranko', 'Šafran,Roko', 'Bekavac,Rozina', 'Dražić,Sandi', 'Šantić,Senija', 'Stošić,Simona', 'Bojić,Slobodan', 'Bošnjak,Smiljka', 'Mrkonjić,Stanislav', 'Mršić,Stjepan', 'Mesarić,Svetlana', 'Dumić,Tena', 'Grbac,Tin', 'Klasić,Toni', 'Matak,Valentino', 'Vidak,Velibor', 'Topić,Vice', 'Krajnović,Vinka', 'Čorak,Vjekoslav', 'Jakopec,Vlado', 'Brlić,Vojislav', 'Šipek,Zagorka', 'Božinović,Zlatan', 'Martinjak,Zorana', 'Marinović,Zvjezdana', 'Mimica,Đina', 'Šimek,Špiro', 'Marušić,Željana']
# Razina 8: ['Ljubičić,', 'Bešlić,Adam', 'Zebić,Adela', 'Špiranec,Adriana', 'Marević,Agata', 'Čižmešija,Aida', 'Janeš,Albert', 'Gržinić,Albina', 'Drmić,Aleksandar', 'Kraljević,Alemka', 'Slavica,Alenka', 'Bosanac,Aljoša', 'Adamović,Alojzija', 'Kolundžić,Alojzije', 'Runje,Ana', 'Raguž,Anamarija', 'Bašić,Andreas', 'Bobanović,Andreja', 'Carević,Andrijana', 'Marević,Ane', 'Kanižaj,Angela', 'Stipanović,Angelina', 'Rakić,Anita', 'Vukman,Anka', 'Orešković,Ante', 'Vrbanec,Anto', 'Gavran,Antonia', 'Pešut,Antonijo', 'Gavranović,Ančica', 'Marijanović,Anđela', 'Vujčić,Anđelina', 'Banović,Anđelo', 'Radaković,Ariana', 'Slavica,Asja', 'Bosnić,Baldo', 'Radoš,Barica', 'Dolić,Benjamin', 'Grujić,Bernard', 'Čuljak,Bernardica', 'Stipanović,Biserka', 'Dedić,Blaž', 'Milardović,Blaženko', 'Kovačec,Bogdanka', 'Gašpar,Bojana', 'Špehar,Borislav', 'Jurjević,Borko', 'Rogulj,Boro', 'Vidović,Boža', 'Pezelj,Božica', 'Matulić,Branislava', 'Lazić,Brigita', 'Alfirević,Cecilija', 'Butković,Cvita', 'Bilandžija,Daliborka', 'Dujić,Damjan', 'Perica,Dane', 'Vidaković,Daniela', 'Kos,Danilo', 'Škrlec,Danira', 'Turkalj,Danko', 'Antolović,Darija', 'Bajić,Dario', 'Zebić,Darko', 'Salopek,Davorin', 'Radojčić,Deana', 'Vukoja,Dejana', 'Posavac,Desanka', 'Golub,Dina', 'Brezak,Dino', 'Anić,Dobrila', 'Brlić,Domagoj', 'Dizdarević,Doris', 'Čaušević,Dorotea', 'Sabljak,Dragan', 'Jandrić,Draginja', 'Kramarić,Dragomir', 'Novoselac,Dražan', 'Jakopec,Draženko', 'Šimunović,Duje', 'Krajnović,Dušanka', 'Pejković,Duško', 'Petek,Edo', 'Kurtović,Elda', 'Gorički,Eleonora', 'Jakšić,Elvira', 'Rebić,Emanuela', 'Vranješ,Emilio', 'Kraljević,Enes', 'Bogunović,Ernest', 'Filipčić,Esad', 'Margetić,Eugen', 'Petković,Evica', 'Kuzmanović,Fanika', 'Lovrenčić,Filip', 'Radoš,Frana', 'Križan,Frane', 'Bulić,Franjka', 'Matić,Franko', 'Košćak,Gizela', 'Novosel,Gorana', 'Dragojević,Gordana', 'Benković,Greta', 'Jelenić,Grgo', 'Štefanec,Hana', 'Miškulin,Helga', 'Varga,Hrvoje', 'Brozović,Ilija', 'Kožić,Ilonka', 'Lukačić,Ines', 'Žaja,Ira', 'Brezak,Irma', 'Andrijanić,Ivana', 'Petak,Ivica', 'Turk,Izabela', 'Majetić,Jagica', 'Marić,Jakov', 'Novaković,Janez', 'Pavlek,Jaroslav', 'Martinčević,Jasminka', 'Špoljarić,Jela', 'Tomac,Jelka', 'Starčević,Jerko', 'Cvitanović,Jordan', 'Štefančić,Josip', 'Sokač,Jovan', 'Štrbac,Jozefina', 'Bogović,Julija', 'Miškulin,Julka', 'Karamatić,Juro', 'Zorić,Karin', 'Vukadin,Karmen', 'Crljen,Kate', 'Kožić,Kazimir', 'Bačić,Klaudija', 'Markota,Klementina', 'Đaković,Kornelija', 'Radočaj,Kristijan', 'Brozović,Krunoslav', 'Aleksić,Ladislav', 'Marušić,Lazar', 'Radaković,Lenka', 'Vukelić,Leon', 'Sinković,Leonardo', 'Stojić,Lina', 'Dumić,Ljeposava', 'Barać,Ljuba', 'Jakovljević,Ljubinka', 'Grabar,Ljubomir', 'Begović,Loredana', 'Marinković,Lovre', 'Rajčić,Luciano', 'Bedeković,Luka', 'Ilić,Magda', 'Draženović,Maja', 'Vranješ,Manda', 'Kljajić,Manuel', 'Kiš,Mara', 'Štefanec,Marcela', 'Bertović,Margita', 'Knežić,Marija', 'Radočaj,Marijana', 'Posavac,Marijeta', 'Mihaljević,Marina', 'Ćorluka,Marinko', 'Barukčić,Marjan', 'Kukec,Marko', 'Mijatović,Marta', 'Ramljak,Mate', 'Cvitan,Mateo', 'Nikić,Matilda', 'Borović,Maša', 'Bistrović,Meri', 'Novaković,Mihael', 'Đorđević,Miho', 'Frančić,Miko', 'Vučić,Milana', 'Margetić,Milenka', 'Oreški,Milivoj', 'Budimir,Milka', 'Stošić,Milojka', 'Vukadin,Milutin', 'Zec,Mirela', 'Šimić,Miroslava', 'Ribić,Mladenka', 'Karlović,Morena', 'Markotić,Natalija', 'Jakopović,Nedeljko', 'Đurđević,Nedjeljka', 'Subotić,Nela', 'Tomičić,Nenad', 'Grozdanić,Nera', 'Crljen,Neva', 'Majdandžić,Nevija', 'Maretić,Nikola', 'Žunić,Ninoslav', 'Tušek,Oto', 'Radošević,Paula', 'Tolić,Pavle', 'Žagar,Pero', 'Kožul,Radivoj', 'Karlović,Rafael', 'Kasunić,Regina', 'Vrbanec,Rita', 'Grozdanić,Romana', 'Vranić,Rosanda', 'Bakić,Rudolf', 'Dumić,Samanta', 'Mlinarić,Sanela', 'Mihaljević,Savo', 'Krstić,Silvano', 'Zadravec,Silvio', 'Kosić,Slaven', 'Ivanušić,Slađana', 'Svalina,Slobodan', 'Franković,Smiljan', 'Marušić,Snežana', 'Lukšić,Srećko', 'Žeravica,Stanko', 'Jagodić,Stipan', 'Križanec,Stojanka', 'Martinčević,Svetin', 'Kneže ...
# Razina 9: ['Dobrić,', 'Petrović,', 'Matanović,Ada', 'Kukić,Adam', 'Grgurević,Adela', 'Ivanić,Adolf', 'Kopić,Adriana', 'Ramljak,Adriano', 'Uvodić,Adrijana', 'Brlić,Agneza', 'Anđelić,Aida', 'Jergović,Alan', 'Županić,Alan', 'Perak,Albert', 'Rupčić,Albin', 'Odak,Albina', 'Lončar,Aldo', 'Olujić,Aleksandar', 'Čović,Aleksandra', 'Uremović,Alemka', 'Gotal,Alenka', 'Bijelić,Alfred', 'Majdandžić,Alica', 'Zirdum,Aljoša', 'Miškulin,Alojz', 'Jugović,Alojzija', 'Bukovac,Alojzije', 'Zubčić,Alojzije', 'Butorac,Ana', 'Golubić,Ana-Marija', 'Hren,Anamarija', 'Čolak,Anamarija', 'Gajski,Andrea', 'Lučić,Andreas', 'Pranjić,Andrej', 'Perić,Andreja', 'Sokač,Andrija', 'Ribarić,Andrijana', 'Sokolić,Andro', 'Žeželj,Ane', 'Škrinjar,Anela', 'Miličević,Angela', 'Kadić,Angelina', 'Buršić,Anica', 'Bukovčan,Anita', 'Franjković,Anja', 'Krsnik,Anka', 'Klarić,Ankica', 'Jurković,Ante', 'Brlečić,Antica', 'Grdić,Anto', 'Markotić,Anton', 'Puškarić,Antonela', 'Smolčić,Antonia', 'Buljan,Antonijo', 'Lucić,Antonio', 'Pejić,Antun', 'Petric,Ančica', 'Skelin,Anđa', 'Ivezić,Anđelija', 'Križan,Anđelina', 'Miloš,Anđelka', 'Prpić,Anđelko', 'Grizelj,Anđelo', 'Čuljak,Anđelo', 'Malenica,Arijana', 'Nikolić,Arsen', 'Jurkić,August', 'Kanižaj,Azra', 'Bebić,Bara', 'Čabraja,Barbara', 'Krizmanić,Bartol', 'Turkalj,Bartul', 'Milić,Benjamin', 'Ćosić,Berislav', 'Čaušević,Bernard', 'Lukačić,Bernardica', 'Kardum,Biljana', 'Jurčević,Biserka', 'Bradarić,Blago', 'Herman,Blanka', 'Raguž,Blaž', 'Jakopec,Blaženko', 'Šimičić,Blaženko', 'Škreblin,Bogdan', 'Živko,Bogdanka', 'Čolak,Bojan', 'Zubović,Bojana', 'Koprivnjak,Borislav', 'Mirković,Borivoj', 'Vujčić,Borka', 'Vrkić,Borko', 'Dragojević,Boro', 'Ivković,Bosilj
# %% [markdown]
# ### f) Implementacija pretrazivanja podataka

# %%
def search_by_prefix(tree, prefix):
    """Vraća listu osoba čije prezime počinje na zadani prefiks (bez zvjezdice)."""
    result = []
    if not tree.root:
        return result
    stack = [tree.root]
    while stack:
        node = stack.pop()
        if node.value.prezime.startswith(prefix):
            result.append(node.value)
        # Ako je prezime veće ili jednako prefiksu, idi lijevo
        if node.left and (node.value.prezime > "Horv" or node.value.prezime.startswith(prefix)):
            stack.append(node.left)
        # Ako je prezime manje ili počinje s prefiksom, idi desno
        if node.right and (node.value.prezime < "Horw" or node.value.prezime.startswith(prefix)):
            stack.append(node.right)
            
    return result
 
# Funkcija za unos i mjerenje vremena pretrage
prefix_input = input("Unesite prezime ili prefiks (npr. Horv*): ").strip()
if prefix_input.endswith("*"):
    prefix = prefix_input[:-1]
else:
    prefix = prefix_input
 
print("\nPretraga u običnom BST stablu...")
start = time.time()
bst_results = search_by_prefix(bst_tree, prefix)
bst_search_time = time.time() - start
print(f"Pronađeno {len(bst_results)} rezultata u BST za prefiks '{prefix}'.")
for osoba in bst_results:
    print(osoba)
print(f"Vrijeme pretrage (BST): {bst_search_time:.6f} s\n")
 
print("Pretraga u AVL stablu...")
start = time.time()
avl_results = search_by_prefix(avl_tree_counted, prefix)
avl_search_time = time.time() - start
print(f"Pronađeno {len(avl_results)} rezultata u AVL za prefiks '{prefix}'.")
for osoba in avl_results:
    print(osoba)
print(f"Vrijeme pretrage (AVL): {avl_search_time:.6f} s\n")
 
if bst_search_time > 0 and avl_search_time > 0:
    print(f"AVL pretraga je {bst_search_time/avl_search_time:.2f}x brža od BST" if bst_search_time > avl_search_time else f"BST pretraga je {avl_search_time/bst_search_time:.2f}x brža od AVL")
# Out:
# Pretraga u običnom BST stablu...
# Pronađeno 4 rezultata u BST za prefiks 'Horv'.
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='10.08.1982', mjesto_stanovanja='Nova Gradiška')
# Osoba(ime='Aida', prezime='Horvatić', spol='Ž', datum_rodenja='15.06.1973', mjesto_stanovanja='Veliko Trgovišće')
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='22.01.1986', mjesto_stanovanja='Garešnica')
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='23.05.1989', mjesto_stanovanja='Čepin')
# Vrijeme pretrage (BST): 0.000000 s
#
# Pretraga u AVL stablu...
# Pronađeno 1 rezultata u AVL za prefiks 'Horv'.
# Osoba(ime='Mateo', prezime='Horvatić', spol='Ž', datum_rodenja='06.08.2006', mjesto_stanovanja='Nin')
# Vrijeme pretrage (AVL): 0.000000 s

# %% [markdown]
# ### g)

# %%
def search_range_by_prefix(tree, prefix_start, prefix_end):
    """Vraća listu osoba čije prezime je u zadanom rangu prefiksa."""
    result = []
    if not tree.root:
        return result
    stack = [tree.root]
    while stack:
        node = stack.pop()
        prezime = node.value.prezime
        if prezime >= prefix_start and prezime <= prefix_end:
            result.append(node.value)
        if node.left and prezime > prefix_start:
            stack.append(node.left)
        if node.right and prezime < prefix_end:
            stack.append(node.right)
    return result
 
# Unos ranga
range_input = input("Unesite rang prezimena (npr. Horv*-Ivo* ili D*-I*): ").strip()
if '-' in range_input:
    start_raw, end_raw = range_input.split('-', 1)
    prefix_start = start_raw.strip().rstrip('*')
    prefix_end = end_raw.strip().rstrip('*')
else:
    prefix_start = range_input.strip().rstrip('*')
    prefix_end = prefix_start
 
print(f"\nPretraga ranga u BST stablu za '{prefix_start}' do '{prefix_end}'...")
start = time.time()
bst_range_results = search_range_by_prefix(bst_tree, prefix_start, prefix_end)
bst_range_time = time.time() - start
print(f"Pronađeno {len(bst_range_results)} rezultata u BST za rang.")
for osoba in bst_range_results:
    print(osoba)
print(f"Vrijeme pretrage (BST): {bst_range_time:.6f} s\n")
 
print(f"Pretraga ranga u AVL stablu za '{prefix_start}' do '{prefix_end}'...")
start = time.time()
avl_range_results = search_range_by_prefix(avl_tree_counted, prefix_start, prefix_end)
avl_range_time = time.time() - start
print(f"Pronađeno {len(avl_range_results)} rezultata u AVL za rang.")
for osoba in avl_range_results:
    print(osoba)
print(f"Vrijeme pretrage (AVL): {avl_range_time:.6f} s\n")
 
if bst_range_time > 0 and avl_range_time > 0:
    print(f"AVL pretraga je {bst_range_time/avl_range_time:.2f}x brža od BST" if bst_range_time > avl_range_time else f"BST pretraga je {avl_range_time/bst_range_time:.2f}x brža od AVL")
# Out:
# Pretraga ranga u BST stablu za 'Horv' do 'Ivo'...
# Pronađeno 30 rezultata u BST za rang.
# Osoba(ime='Aida', prezime='Ilić', spol='Ž', datum_rodenja='14.02.1979', mjesto_stanovanja='Kutina')
# Osoba(ime='Aida', prezime='Ivanović', spol='Ž', datum_rodenja='13.01.1984', mjesto_stanovanja='Selnica')
# Osoba(ime='Aida', prezime='Ivezić', spol='Ž', datum_rodenja='13.04.1991', mjesto_stanovanja='Barilović')
# Osoba(ime='Aida', prezime='Ivković', spol='Ž', datum_rodenja='23.12.2007', mjesto_stanovanja='Velika Kopanica')
# Osoba(ime='Aida', prezime='Ivančan', spol='Ž', datum_rodenja='13.05.1996', mjesto_stanovanja='Gračišće')
# Osoba(ime='Aida', prezime='Ivančević', spol='Ž', datum_rodenja='20.09.1984', mjesto_stanovanja='Pićan')
# Osoba(ime='Aida', prezime='Ivančević', spol='Ž', datum_rodenja='04.03.1982', mjesto_stanovanja='Ivankovo')
# Osoba(ime='Aida', prezime='Ivanović', spol='Ž', datum_rodenja='16.08.1985', mjesto_stanovanja='Feričanci')
# Osoba(ime='Aida', prezime='Ivandić', spol='Ž', datum_rodenja='04.08.1971', mjesto_stanovanja='Senj')
# Osoba(ime='Aida', prezime='Ivanić', spol='Ž', datum_rodenja='08.07.2004', mjesto_stanovanja='Gornji Bogićevci')
# Osoba(ime='Aida', prezime='Ivanišević', spol='Ž', datum_rodenja='15.09.1991', mjesto_stanovanja='Hlebine')
# Osoba(ime='Aida', prezime='Ivanković', spol='Ž', datum_rodenja='24.03.1993', mjesto_stanovanja='Kapela')
# Osoba(ime='Aida', prezime='Ivanišević', spol='Ž', datum_rodenja='06.07.2005', mjesto_stanovanja='Blato')
# Osoba(ime='Aida', prezime='Ivanić', spol='Ž', datum_rodenja='11.07.2002', mjesto_stanovanja='Pula-Pola')
# Osoba(ime='Aida', prezime='Ivanić', spol='Ž', datum_rodenja='12.02.1983', mjesto_stanovanja='Čaglin')
# Osoba(ime='Aida', prezime='Ivandić', spol='Ž', datum_rodenja='07.03.1972', mjesto_stanovanja='Rešetari')
# Osoba(ime='Aida', prezime='Hren', spol='Ž', datum_rodenja='10.03.1968', mjesto_stanovanja='Belišće')
# Osoba(ime='Aida', prezime='Hrženjak', spol='Ž', datum_rodenja='02.05.1961', mjesto_stanovanja='Mali Lošinj')
# Osoba(ime='Aida', prezime='Husnjak', spol='Ž', datum_rodenja='21.12.1969', mjesto_stanovanja='Vodnjan-Dignano')
# Osoba(ime='Aida', prezime='Husnjak', spol='Ž', datum_rodenja='01.08.1987', mjesto_stanovanja='Lupoglav')
# Osoba(ime='Aida', prezime='Husnjak', spol='Ž', datum_rodenja='16.06.1986', mjesto_stanovanja='Tisno')
# Osoba(ime='Aida', prezime='Hršak', spol='Ž', datum_rodenja='31.10.1984', mjesto_stanovanja='Oprtalj-Portole')
# Osoba(ime='Aida', prezime='Hren', spol='Ž', datum_rodenja='22.04.2008', mjesto_stanovanja='Blato')
# Osoba(ime='Aida', prezime='Hršak', spol='Ž', datum_rodenja='16.09.1990', mjesto_stanovanja='Nova Bukovica')
# Osoba(ime='Aida', prezime='Hren', spol='Ž', datum_rodenja='20.11.2002', mjesto_stanovanja='Bilje')
# Osoba(ime='Aida', prezime='Hren', spol='Ž', datum_rodenja='10.07.1985', mjesto_stanovanja='Biograd na Moru')
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='10.08.1982', mjesto_stanovanja='Nova Gradiška')
# Osoba(ime='Aida', prezime='Horvatić', spol='Ž', datum_rodenja='15.06.1973', mjesto_stanovanja='Veliko Trgovišće')
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='22.01.1986', mjesto_stanovanja='Garešnica')
# Osoba(ime='Aida', prezime='Horvat', spol='Ž', datum_rodenja='23.05.1989', mjesto_stanovanja='Čepin')
# Vrijeme pretrage (BST): 0.000998 s
#
# Pretraga ranga u AVL stablu za 'Horv' do 'Ivo'...
# Pronađeno 37 rezultata u AVL za rang.
# Osoba(ime='Mateo', prezime='Ivanušić', spol='M', datum_rodenja='08.06.1967', mjesto_stanovanja='Primošten')
# Osoba(ime='Mateo', prezime='Ivezić', spol='Ž', datum_rodenja='22.04.2009', mjesto_stanovanja='Otok')
# Osoba(ime='Mateo', prezime='Ivić', spol='Ž', datum_rodenja='04.04.1974', mjesto_stanovanja='Legrad')
# Osoba(ime='Mateo', prezime='Ivezić', spol='M', datum_rodenja='04.01.1984', mjesto_stanovanja='Milna')
# Osoba(ime='Mateo', prezime='Ivezić', spol='M', datum_rodenja='12.02.1965', mjesto_stanovanja='Lokvičići')
# Osoba(ime='Mateo', prezime='Ivezić', spol='M', datum_rodenja='18.04.1999', mjesto_stanovanja='Našice')
# Osoba(ime='Mateo', prezime='Ivančan', spol='M', datum_rodenja='27.12.1984', mjesto_stanovanja='Sokolovac')
# Osoba(ime='Mateo', prezime='Ivančić', spol='M', datum_rodenja='17.12.1999', mjesto_stanovanja='Šodolovci')
# Osoba(ime='Mateo', prezime='Ivančić', spol='Ž', datum_rodenja='21.09.2005', mjesto_stanovanja='Čaglin')
# Osoba(ime='Mateo', prezime='Ivanušić', spol='Ž', datum_rodenja='18.12.1966', mjesto_stanovanja='Semeljci')
# Osoba(ime='Mateo', prezime='Hrvatin', spol='Ž', datum_rodenja='11.12.1968', mjesto_stanovanja='Janjina')
# Osoba(ime='Mateo', prezime='Huzjak', spol='Ž', datum_rodenja='20.12.1988', mjesto_stanovanja='Gola')
# Osoba(ime='Mateo', prezime='Ivanić', spol='M', datum_rodenja='16.03.1987', mjesto_stanovanja='Kloštar Podravski')
# Osoba(ime='Mateo', prezime='Ivanović', spol='M', datum_rodenja='23.03.1994', mjesto_stanovanja='Kaštela')
# Osoba(ime='Mateo', prezime='Ivanović', spol='Ž', datum_rodenja='07.02.1996', mjesto_stanovanja='Zabok')
# Osoba(ime='Mateo', prezime='Ivanović', spol='Ž', datum_rodenja='13.03.1977', mjesto_stanovanja='Žminj')
# Osoba(ime='Mateo', prezime='Ivanović', spol='M', datum_rodenja='29.03.1973', mjesto_stanovanja='Šenkovec')
# Osoba(ime='Mateo', prezime='Ivanišević', spol='Ž', datum_rodenja='02.03.1967', mjesto_stanovanja='Pag')
# Osoba(ime='Mateo', prezime='Ivanković', spol='M', datum_rodenja='21.02.1978', mjesto_stanovanja='Lokve')
# Osoba(ime='Mateo', prezime='Ivanić', spol='Ž', datum_rodenja='02.01.1966', mjesto_stanovanja='Sopje')
# Osoba(ime='Mateo', prezime='Ivandić', spol='Ž', datum_rodenja='03.06.1969', mjesto_stanovanja='Mošćenička Draga')
# Osoba(ime='Mateo', prezime='Ivandić', spol='Ž', datum_rodenja='09.02.1994', mjesto_stanovanja='Senj')
# Osoba(ime='Mateo', prezime='Ivanić', spol='M', datum_rodenja='14.12.2002', mjesto_stanovanja='Koprivnički Bregi')
# Osoba(ime='Mateo', prezime='Ivandić', spol='Ž', datum_rodenja='06.02.1982', mjesto_stanovanja='Sveti Ivan Zelina')
# Osoba(ime='Mateo', prezime='Ilić', spol='Ž', datum_rodenja='16.11.1971', mjesto_stanovanja='Duga Resa')
# Osoba(ime='Mateo', prezime='Hrženjak', spol='M', datum_rodenja='23.02.1980', mjesto_stanovanja='Staro Petrovo Selo')
# Osoba(ime='Mateo', prezime='Huzjak', spol='M', datum_rodenja='06.04.1962', mjesto_stanovanja='Muć')
# Osoba(ime='Mateo', prezime='Huzjak', spol='M', datum_rodenja='17.04.1965', mjesto_stanovanja='Klakar')
# Osoba(ime='Mateo', prezime='Huzjak', spol='Ž', datum_rodenja='03.07.2008', mjesto_stanovanja='Imotski')
# Osoba(ime='Mateo', prezime='Husnjak', spol='M', datum_rodenja='23.05.1977', mjesto_stanovanja='Bistra')
# Osoba(ime='Mateo', prezime='Husnjak', spol='Ž', datum_rodenja='11.08.1995', mjesto_stanovanja='Primošten')
# Osoba(ime='Mateo', prezime='Hršak', spol='M', datum_rodenja='12.08.1970', mjesto_stanovanja='Negoslavci')
# Osoba(ime='Mateo', prezime='Hrženjak', spol='M', datum_rodenja='03.05.2008', mjesto_stanovanja='Novi Golubovec')
# Osoba(ime='Mateo', prezime='Hršak', spol='M', datum_rodenja='01.04.2009', mjesto_stanovanja='Prgomet')
# Osoba(ime='Mateo', prezime='Hršak', spol='M', datum_rodenja='10.06.1964', mjesto_stanovanja='Lukač')
# Osoba(ime='Mateo', prezime='Horvatić', spol='Ž', datum_rodenja='06.08.2006', mjesto_stanovanja='Nin')
# Osoba(ime='Mateo', prezime='Hren', spol='Ž', datum_rodenja='28.09.1963', mjesto_stanovanja='Lovas')
# Vrijeme pretrage (AVL): 0.000000 s

# %% [markdown]
# ### h)

# %%
import time
import random
import copy
 
# Algoritmi sortiranja
 
def insertion_sort(arr, key=lambda x: x):
    a = arr.copy()
    for i in range(1, len(a)):
        j = i
        while j > 0 and key(a[j-1]) > key(a[j]):
            a[j-1], a[j] = a[j], a[j-1]
            j -= 1
    return a
 
def merge_sort(arr, key=lambda x: x):
    if len(arr) <= 1:
        return arr.copy()
    mid = len(arr) // 2
    left = merge_sort(arr[:mid], key)
    right = merge_sort(arr[mid:], key)
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if key(left[i]) <= key(right[j]):
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
 
def quick_sort(arr, key=lambda x: x):
    a = arr.copy()
    def _qs(a, l, r):
        if l < r:
            pi = partition(a, l, r)
            _qs(a, l, pi-1)
            _qs(a, pi+1, r)
    def partition(a, l, r):
        pivot = key(a[r])
        i = l-1
        for j in range(l, r):
            if key(a[j]) <= pivot:
                i += 1
                a[i], a[j] = a[j], a[i]
        a[i+1], a[r] = a[r], a[i+1]
        return i+1
    _qs(a, 0, len(a)-1)
    return a
 
def tree_sort(arr, key=lambda x: x):
    tree = AVLSearchTree()
    for x in arr:
        tree.add(x)
    return list(tree)
 
# Funkcija za mjerenje vremena
 
def measure_sort_time(sort_fn, arr, key):
    start = time.time()
    sorted_arr = sort_fn(arr, key=key)
    elapsed = time.time() - start
    return sorted_arr, elapsed
 
# Ključ sortiranja: prezime, ime
sort_key = lambda o: (o.prezime, o.ime)
 
# Veličine podskupova
#sizes = [1000, 2000, 5000, 10000, 20000, 50000, 100000]

sizes = [1000, 2000, 5000, 10000, 20000, 50000]
 
print("\n===== USPOREDBA ALGORITAMA SORTIRANJA =====\n")
for size in sizes:
    if size > len(osobe):
        break
    print(f"\nPodskup veličine: {size}")
    subset = random.sample(osobe, size)
   
    # Insertion sort
    res1, t_insertion = measure_sort_time(insertion_sort, subset, sort_key)
    print(f"Insertion sort: {t_insertion:.4f} s")
   
    # Merge sort
    res2, t_merge = measure_sort_time(merge_sort, subset, sort_key)
    print(f"Merge sort: {t_merge:.4f} s")
   
    # Quick sort
    res3, t_quick = measure_sort_time(quick_sort, subset, sort_key)
    print(f"Quick sort: {t_quick:.4f} s")
   
    # Tree sort (AVL)
    res4, t_tree = measure_sort_time(tree_sort, subset, sort_key)
    print(f"Tree sort (AVL): {t_tree:.4f} s")

    print(res1[:10])
    print(res2[:10])
    print(res3[:10])
    print(res4[:10])
# Out:
# ===== USPOREDBA ALGORITAMA SORTIRANJA =====
#
#
# Podskup veličine: 1000
# Insertion sort: 0.0507 s
# Merge sort: 0.0020 s
# Quick sort: 0.0020 s
# Tree sort (AVL): 0.0060 s
# [Osoba(ime='Emanuel', prezime='Abramović', spol='M', datum_rodenja='03.01.2009', mjesto_stanovanja='Korčula'), Osoba(ime='Ingrid', prezime='Abramović', spol='Ž', datum_rodenja='10.09.1966', mjesto_stanovanja='Netretić'), Osoba(ime='Irma', prezime='Abramović', spol='Ž', datum_rodenja='21.02.1974', mjesto_stanovanja='Slivno'), Osoba(ime='Slavka', prezime='Abramović', spol='Ž', datum_rodenja='25.08.1991', mjesto_stanovanja='Stupnik'), Osoba(ime='Zvjezdana', prezime='Andrijanić', spol='Ž', datum_rodenja='07.02.1973', mjesto_stanovanja='Draž'), Osoba(ime='Marjan', prezime='Andrijašević', spol='M', datum_rodenja='02.11.1975', mjesto_stanovanja='Hum na Sutli'), Osoba(ime='Milanka', prezime='Andrijašević', spol='Ž', datum_rodenja='03.10.2003', mjesto_stanovanja='Rogoznica'), Osoba(ime='Lazar', prezime='Andrić', spol='M', datum_rodenja='31.10.1966', mjesto_stanovanja='Čeminac'), Osoba(ime='Zlatan', prezime='Anić', spol='M', datum_rodenja='15.12.1979', mjesto_stanovanja='Pitomača'), Osoba(ime='Florijan', prezime='Antunović', spol='M', datum_rodenja='16.11.1975', mjesto_stanovanja='Rešetari')]
# [Osoba(ime='Emanuel', prezime='Abramović', spol='M', datum_rodenja='03.01.2009', mjesto_stanovanja='Korčula'), Osoba(ime='Ingrid', prezime='Abramović', spol='Ž', datum_rodenja='10.09.1966', mjesto_stanovanja='Netretić'), Osoba(ime='Irma', prezime='Abramović', spol='Ž', datum_rodenja='21.02.1974', mjesto_stanovanja='Slivno'), Osoba(ime='Slavka', prezime='Abramović', spol='Ž', datum_rodenja='25.08.1991', mjesto_stanovanja='Stupnik'), Osoba(ime='Zvjezdana', prezime='Andrijanić', spol='Ž', datum_rodenja='07.02.1973', mjesto_stanovanja='Draž'), Osoba(ime='Marjan', prezime='Andrijašević', spol='M', datum_rodenja='02.11.1975', mjesto_stanovanja='Hum na Sutli'), Osoba(ime='Milanka', prezime='Andrijašević', spol='Ž', datum_rodenja='03.10.2003', mjesto_stanovanja='Rogoznica'), Osoba(ime='Lazar', prezime='Andrić', spol='M', datum_rodenja='31.10.1966', mjesto_stanovanja='Čeminac'), Osoba(ime='Zlatan', prezime='Anić', spol='M', datum_rodenja='15.12.1979', mjesto_stanovanja='Pitomača'), Osoba(ime='Florijan', prezime='Antunović', spol='M', datum_rodenja='16.11.1975', mjesto_stanovanja='Rešetari')]
# [Osoba(ime='Emanuel', prezime='Abramović', spol='M', datum_rodenja='03.01.2009', mjesto_stanovanja='Korčula'), Osoba(ime='Ingrid', prezime='Abramović', spol='Ž', datum_rodenja='10.09.1966', mjesto_stanovanja='Netretić'), Osoba(ime='Irma', prezime='Abramović', spol='Ž', datum_rodenja='21.02.1974', mjesto_stanovanja='Slivno'), Osoba(ime='Slavka', prezime='Abramović', spol='Ž', datum_rodenja='25.08.1991', mjesto_stanovanja='Stupnik'), Osoba(ime='Zvjezdana', prezime='Andrijanić', spol='Ž', datum_rodenja='07.02.1973', mjesto_stanovanja='Draž'), Osoba(ime='Marjan', prezime='Andrijašević', spol='M', datum_rodenja='02.11.1975', mjesto_stanovanja='Hum na Sutli'), Osoba(ime='Milanka', prezime='Andrijašević', spol='Ž', datum_rodenja='03.10.2003', mjesto_stanovanja='Rogoznica'), Osoba(ime='Lazar', prezime='Andrić', spol='M', datum_rodenja='31.10.1966', mjesto_stanovanja='Čeminac'), Osoba(ime='Zlatan', prezime='Anić', spol='M', datum_rodenja='15.12.1979', mjesto_stanovanja='Pitomača'), Osoba(ime='Florijan', prezime='Antunović', spol='M', datum_rodenja='16.11.1975', mjesto_stanovanja='Rešetari')]
# [Osoba(ime='Ada', prezime='Gotal', spol='Ž', datum_rodenja='24.02.1961', mjesto_stanovanja='Otok'), Osoba(ime='Adam', prezime='Jambrešić', spol='M', datum_rodenja='06.06.1987', mjesto_stanovanja='Donji Kukuruzari'), Osoba(ime='Adolf', prezime='Žarković', spol='M', datum_rodenja='12.10.1978', mjesto_stanovanja='Bedekovčina'), Osoba(ime='Adriana', prezime='Debeljak', spol='Ž', datum_rodenja='06.11.1994', mjesto_stanovanja='Primošten'), Osoba(ime='Adriana', prezime='Štefanac', spol='Ž', datum_rodenja='22.03.1968', mjesto_stanovanja='Cernik'), Osoba(ime='Adriano', prezime='Dražić', spol='M', datum_rodenja='29.11.1980', mjesto_stanovanja='Slunj'), Osoba(ime='Adriano', prezime='Đaković', spol='M', datum_rodenja='21.05.2001', mjesto_stanovanja='Pučišća'), Osoba(ime='Adrijana', prezime='Kvesić', spol='Ž', datum_rodenja='02.07.1991', mjesto_stanovanja='Mošćenička Draga'), Osoba(ime='Adrijana', prezime='Zorić', spol='Ž', datum_rodenja='07.02.2006', mjesto_stanovanja='Gornja Stubica'), Osoba(ime='Agneza', prezime='Dukarić', spol='Ž', datum_rodenja='01.04.1983', mjesto_stanovanja='Dobrinj')]
#
# Podskup veličine: 2000
# Insertion sort: 0.2046 s
# Merge sort: 0.0059 s
2002', mjesto_stanovanja='Mljet'), Osoba(ime='Jelica', prezime='Abramović', spol='Ž', datum_rodenja='25.07.1999', mjesto_stanovanja='Sveti Ivan Žabno'), Osoba(ime='Marijan', prezime='Abramović', spol='M', datum_rodenja='17.11.2004', mjesto_stanovanja='Skrad'), Osoba(ime='Marijo', prezime='Abramović', spol='M', datum_rodenja='19.05.1967', mjesto_stanovanja='Galovac'), Osoba(ime='Nađa', prezime='Abramović', spol='Ž', datum_rodenja='20.08.1993', mjesto_stanovanja='Novigrad'), Osoba(ime='Radomir', prezime='Abramović', spol='M', datum_rodenja='07.02.2000', mjesto_stanovanja='Donji Kukuruzari'), Osoba(ime='Roberto', prezime='Abramović', spol='M', datum_rodenja='28.01.1984', mjesto_stanovanja='Bedenica')]
# [Osoba(ime='', prezime='Begić', spol='Ž', datum_rodenja='07.12.2004', mjesto_stanovanja='Stubičke Toplice'), Osoba(ime='', prezime='Brekalo', spol='Ž', datum_rodenja='24.04.1976', mjesto_stanovanja='Opatija'), Osoba(ime='', prezime='Brezak', spol='Ž', datum_rodenja='28.10.1974', mjesto_stanovanja='Donji Lapac'), Osoba(ime='', prezime='Bulat', spol='Ž', datum_rodenja='04.03.1982', mjesto_stanovanja='Gračac'), Osoba(ime='', prezime='Dadić', spol='Ž', datum_rodenja='06.04.2009', mjesto_stanovanja='Korčula'), Osoba(ime='', prezime='Dorić', spol='Ž', datum_rodenja='22.11.2008', mjesto_stanovanja='Kaštela'), Osoba(ime='', prezime='Draganić', spol='Ž', datum_rodenja='20.03.1986', mjesto_stanovanja='Gvozd'), Osoba(ime='', prezime='Gorički', spol='Ž', datum_rodenja='28.12.1981', mjesto_stanovanja='Povljana'), Osoba(ime='', prezime='Grbac', spol='Ž', datum_rodenja='25.03.2004', mjesto_stanovanja='Oroslavje'), Osoba(ime='', prezime='Hercigonja', spol='Ž', datum_rodenja='20.12.1997', mjesto_stanovanja='Hum na Sutli')]
#
# Podskup veličine: 50000
# Insertion sort: 272.1358 s
# Merge sort: 0.2520 s
# Quick sort: 0.2047 s
# Tree sort (AVL): 0.5831 s
# [Osoba(ime='Aida', prezime='Abramović', spol='Ž', datum_rodenja='05.05.1971', mjesto_stanovanja='Šodolovci'), Osoba(ime='Amalija', prezime='Abramović', spol='Ž', datum_rodenja='31.10.1974', mjesto_stanovanja='Lanišće'), Osoba(ime='Ana-Marija', prezime='Abramović', spol='Ž', datum_rodenja='02.09.2007', mjesto_stanovanja='Nova Kapela'), Osoba(ime='Angelina', prezime='Abramović', spol='Ž', datum_rodenja='07.07.1974', mjesto_stanovanja='Velika'), Osoba(ime='Antonia', prezime='Abramović', spol='Ž', datum_rodenja='29.03.1973', mjesto_stanovanja='Žakanje'), Osoba(ime='Blanka', prezime='Abramović', spol='Ž', datum_rodenja='04.04.1967', mjesto_stanovanja='Rakovica'), Osoba(ime='Bojan', prezime='Abramović', spol='M', datum_rodenja='19.01.1981', mjesto_stanovanja='Čavle'), Osoba(ime='Borko', prezime='Abramović', spol='M', datum_rodenja='30.04.1961', mjesto_stanovanja='Promina'), Osoba(ime='Budimir', prezime='Abramović', spol='M', datum_rodenja='08.06.1967', mjesto_stanovanja='Preseka'), Osoba(ime='Dragomir', prezime='Abramović', spol='M', datum_rodenja='15.11.1971', mjesto_stanovanja='Levanjska Varoš')]
# [Osoba(ime='', prezime='Aleksić', spol='Ž', datum_rodenja='30.10.2008', mjesto_stanovanja='Sveti Petar u Šumi'), Osoba(ime='', prezime='Anić', spol='Ž', datum_rodenja='11.08.1966', mjesto_stanovanja='Đurđenovac'), Osoba(ime='', prezime='Balić', spol='Ž', datum_rodenja='03.03.2004', mjesto_stanovanja='Mače'), Osoba(ime='', prezime='Bačić', spol='Ž', datum_rodenja='26.05.1976', mjesto_stanovanja='Imotski'), Osoba(ime='', prezime='Benko', spol='Ž', datum_rodenja='20.12.1972', mjesto_stanovanja='Jalžabet'), Osoba(ime='', prezime='Bezjak', spol='Ž', datum_rodenja='24.08.1985', mjesto_stanovanja='Pirovac'), Osoba(ime='', prezime='Bilić', spol='Ž', datum_rodenja='22.01.1998', mjesto_stanovanja='Lovas'), Osoba(ime='', prezime='Bićanić', spol='Ž', datum_rodenja='03.01.1971', mjesto_stanovanja='Marija Gorica'), Osoba(ime='', prezime='Bićanić', spol='Ž', datum_rodenja='23.05.1994', mjesto_stanovanja='Štrigova'), Osoba(ime='', prezime='Blažeković', spol='Ž', datum_rodenja='23.11.1997', mjesto_stanovanja='Županja')]

# %% [markdown]
# #### i) Indeksirano po datummu rođenja

# %%
from datetime import datetime

# Redefinicija klasa

class PersonAVLNode(BinaryNode):
    def compareTo(self, other):
        """
        Compare persons by datum_rodenja (date of birth).
        Older people come first.
        """
        if not isinstance(other, Osoba):
            return super().compareTo(other)

        # Convert string to datetime
        self_date = datetime.strptime(self.value.datum_rodenja, "%d.%m.%Y")
        other_date = datetime.strptime(other.datum_rodenja, "%d.%m.%Y")

        if self_date < other_date:
            return -1
        elif self_date > other_date:
            return 1
        else:
            return 0
        
class PersonBinaryNode(BinaryNode):
    def compareTo(self, other):
        if not isinstance(other, Osoba):
            return super().compareTo(other)

        self_date = datetime.strptime(self.value.datum_rodenja, "%d.%m.%Y")
        other_date = datetime.strptime(other.datum_rodenja, "%d.%m.%Y")

        if self_date < other_date:
            return -1
        elif self_date > other_date:
            return 1
        else:
            return 0
        

# b)

# Izgradnja običnog BST
print("Izgradnja običnog BST stabla...")
start_time = time.time()
bst_tree = BinarySearchTree()
test_osobe = osobe  # Koristimo sve podatke
for osoba in test_osobe:
    bst_tree.add(osoba)
bst_time = time.time() - start_time
bst_height = bst_tree.root.height if bst_tree.root else 0
print(f"Obično BST stablo izgrađeno u {bst_time:.4f} sekundi. Visina: {bst_height}")

# Izgradnja AVL stabla
print("Izgradnja AVL stabla...")
start_time = time.time()
avl_tree = AVLSearchTree()
for osoba in test_osobe:
    avl_tree.add(osoba)
avl_time = time.time() - start_time
avl_height = avl_tree.root.height if avl_tree.root else 0
print(f"AVL stablo izgrađeno u {avl_time:.4f} sekundi. Visina: {avl_height}")

print(f"\nUsporedba vremena izgradnje:")
print(f"Obično BST: {bst_time:.4f} s")
print(f"AVL: {avl_time:.4f} s")
print(f"AVL je {bst_time/avl_time:.2f}x brže od običnog BST" if bst_time > avl_time else f"Obično BST je {avl_time/bst_time:.2f}x brže od AVL")


# c)

def get_min_max_from_tree(tree):
    """Pronalazi minimalnu i maksimalnu vrijednost u stablu (inorder traversal)."""
    if not tree.root:
        return None, None
    
    values = list(tree)
    return values[0], values[-1]

# Pronalaženje min/max za BST
bst_min, bst_max = get_min_max_from_tree(bst_tree)
print("=" * 60)
print("MINIMALNA I MAKSIMALNA VRIJEDNOST INDEKSA")
print("=" * 60)
print("\nObično BST:")
if bst_min:
    print(f"Minimalna vrijednost (prezime): {format_person_name(bst_min)}")
    print(f"  Podaci: Ime={bst_min.ime or '<prazno>'}, Prezime={bst_min.prezime}, Spol={bst_min.spol}, Datum={bst_min.datum_rodenja}, Mjesto={bst_min.mjesto_stanovanja}")
if bst_max:
    print(f"Maksimalna vrijednost (prezime): {format_person_name(bst_max)}")
    print(f"  Podaci: Ime={bst_max.ime or '<prazno>'}, Prezime={bst_max.prezime}, Spol={bst_max.spol}, Datum={bst_max.datum_rodenja}, Mjesto={bst_max.mjesto_stanovanja}")

# Pronalaženje min/max za AVL
avl_min, avl_max = get_min_max_from_tree(avl_tree)
print("\nAVL stablo:")
if avl_min:
    print(f"Minimalna vrijednost (prezime): {format_person_name(avl_min)}")
    print(f"  Podaci: Ime={avl_min.ime or '<prazno>'}, Prezime={avl_min.prezime}, Spol={avl_min.spol}, Datum={avl_min.datum_rodenja}, Mjesto={avl_min.mjesto_stanovanja}")
if avl_max:
    print(f"Maksimalna vrijednost (prezime): {format_person_name(avl_max)}")
    print(f"  Podaci: Ime={avl_max.ime or '<prazno>'}, Prezime={avl_max.prezime}, Spol={avl_max.spol}, Datum={avl_max.datum_rodenja}, Mjesto={avl_max.mjesto_stanovanja}")


# d)

print("\n" + "=" * 60)
print("BROJ ROTACIJA PRI IZGRADNJI AVL STABLA")
print("=" * 60)

# Resetiraj brojače i ponovno izgradi AVL stablo
PersonAVLNode.rotation_count = 0
PersonAVLNode.left_rotation_count = 0
PersonAVLNode.right_rotation_count = 0

avl_tree_counted = AVLSearchTree()
for osoba in test_osobe:
    avl_tree_counted.add(osoba)

stats = avl_tree_counted.get_rotation_stats()
print(f"\nRotacije pri izgradnji AVL stabla:")
print(f"  Ukupno rotacija: {stats['total']}")
print(f"  Lijeve rotacije: {stats['left']}")
print(f"  Desne rotacije: {stats['right']}")


# e)

from collections import deque

def print_tree_by_levels(tree, max_levels=10):
    """Ispisuje stablo po razinama (level-order traversal) do max_levels razina."""
    if not tree.root:
        print("Stablo je prazno.")
        return
    
    queue = deque([(tree.root, 0)])  # (čvor, razina)
    current_level = 0
    level_nodes = []
    
    while queue and current_level < max_levels:
        node, level = queue.popleft()
        
        if level > current_level:
            # Ispisuj prethodnu razinu
            print(f"Razina {current_level}: {level_nodes}")
            level_nodes = []
            current_level = level
        
        if current_level < max_levels:
            # Dodaj prezime i ime čvora
            level_nodes.append(f"{node.value.datum_rodenja}")
            
            if node.left:
                queue.append((node.left, level + 1))
            if node.right:
                queue.append((node.right, level + 1))
    
    if level_nodes:
        print(f"Razina {current_level}: {level_nodes}")

print("\n" + "=" * 60)
print("ISPIS STABLA PO RAZINAMA (PRVIH 10 RAZINA)")
print("=" * 60)

print("\nObično BST:")
print_tree_by_levels(bst_tree, max_levels=10)

print("\nAVL stablo:")
print_tree_by_levels(avl_tree_counted, max_levels=10)
# Out:
# Izgradnja običnog BST stabla...
# Obično BST stablo izgrađeno u 16.8297 sekundi. Visina: 23
# Izgradnja AVL stabla...
# AVL stablo izgrađeno u 20.4615 sekundi. Visina: 23
#
# Usporedba vremena izgradnje:
# Obično BST: 16.8297 s
# AVL: 20.4615 s
# Obično BST je 1.22x brže od AVL
# ============================================================
# MINIMALNA I MAKSIMALNA VRIJEDNOST INDEKSA
# ============================================================
#
# Obično BST:
# Minimalna vrijednost (prezime): Abramović, <prazno>
#   Podaci: Ime=<prazno>, Prezime=Abramović, Spol=Ž, Datum=18.01.1989, Mjesto=Velika Ludina
# Maksimalna vrijednost (prezime): Žunić, Živko
#   Podaci: Ime=Živko, Prezime=Žunić, Spol=M, Datum=29.03.2005, Mjesto=Unešić
#
# AVL stablo:
# Minimalna vrijednost (prezime): Abramović, <prazno>
#   Podaci: Ime=<prazno>, Prezime=Abramović, Spol=Ž, Datum=18.01.1989, Mjesto=Velika Ludina
# Maksimalna vrijednost (prezime): Žunić, Živko
#   Podaci: Ime=Živko, Prezime=Žunić, Spol=M, Datum=29.03.2005, Mjesto=Unešić
#
# ============================================================
# BROJ ROTACIJA PRI IZGRADNJI AVL STABLA
# ============================================================
#
# Rotacije pri izgradnji AVL stabla:
#   Ukupno rotacija: 0
#   Lijeve rotacije: 0
#   Desne rotacije: 0
#
# ============================================================
# ISPIS STABLA PO RAZINAMA (PRVIH 10 RAZINA)
# ============================================================
#
# Obično BST:
# Razina 0: ['29.09.1981']
# Razina 1: ['20.07.2001', '21.05.1962']
# Razina 2: ['30.12.1972', '17.10.1995', '19.07.1961', '13.08.1962']
# Razina 3: ['10.09.1978', '08.04.1981', '26.07.1976', '03.03.1974', '07.12.1976', '02.08.1975', '26.10.1961', '30.03.1964']
# Razina 4: ['23.03.1986', '19.10.1991', '18.02.1976', '01.03.1977', '13.12.1966', '11.07.2001', '21.08.2009', '06.06.1969', '20.08.1983', '12.06.1968', '25.10.2009', '07.08.1995', '16.06.1968', '30.11.1971', '06.03.1984', '28.12.2000']
# Razina 5: ['28.09.2004', '13.09.1981', '03.03.1982', '25.10.2001', '02.02.1987', '01.08.1970', '05.11.1982', '20.04.1991', '04.05.1996', '04.08.1986', '26.02.1985', '20.04.1993', '15.09.1983', '27.03.2001', '12.12.1981', '31.12.1984', '17.08.1984', '14.12.1962', '16.10.1972', '12.07.1975', '28.08.1994', '16.11.1978', '20.09.1992', '26.04.1985', '16.12.1975', '17.06.1961', '06.04.1980', '30.05.1984', '01.07.1972', '04.06.1995', '11.08.1970', '20.11.1971']
